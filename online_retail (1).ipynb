# %% [markdown]
# ## Setup and Imports

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

#formatting command so tht pandas doesn't truncate (shortens the data to preserve memory) 
pd.set_option('display.max_columns', None)

print("Environment setup complete.")
# Out:
# Environment setup complete.

# %%
df=pd.read_csv('online_retail.csv', encoding='ISO-8859-1')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
print(f"Dataset Shape: {df.shape}\n") #Tells rows and columns
print("Column Info")
df.info() #Tells data type and memory usage
print("Numberical Summary")
df.describe() #Gives mean, min, max, standard deviation
# Out:
# Dataset Shape: (541909, 8)
#
# Column Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# Numberical Summary
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ## Data Cleaning (Missing values)

# %%
#Check for missing or null values per column
missing_data=df.isnull().sum()
print("Missing values per column:")
print(missing_data)
# Out:
# Missing values per column:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#Drop rows where CustomerID is null and modify the dataframe in place
df_clean=df.dropna(subset=['CustomerID']).copy()

print(f"Rows remaining after dropping missing IDs: {df_clean.shape[0]}")
# Out:
# Rows remaining after dropping missing IDs: 406829

# %% [markdown]
# ## Isolate Outliers using IQR (Interquartile Range)

# %%
df_clean['TotalSales']=df_clean['Quantity']*df_clean['UnitPrice']

'''
To calculate bounds we use below:
IQR = Q3 - Q1
Lower Bound = Q1 - (1.5 * IQR)
Upper Bound = Q3 + (1.5 * IQR)

(any data point fallin oustide these boundaries is considered an outlier)
'''

# Calculate the 25th (Q1) and 75th (Q3) percentiles
Q1 = df_clean['TotalSales'].quantile(0.25)
Q3 = df_clean['TotalSales'].quantile(0.75)
IQR = Q3 - Q1

#Boundary walls definition
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

#Separate standard transactions from the extreme anomalies
standard_sales = df_clean[(df_clean['TotalSales']>=lower_bound) & (df_clean['TotalSales']<=upper_bound)]
outliers = df_clean[(df_clean['TotalSales']<lower_bound) | (df_clean['TotalSales']>upper_bound)]

print(f"Standard Transactions: {standard_sales.shape[0]} rows")
print(f"Anomalous Transactions: {outliers.shape[0]} rows")
# Out:
# Standard Transactions: 373649 rows
# Anomalous Transactions: 33180 rows

# %% [markdown]
# ## Aggregating Data for Month-Over-Month (MoM) growth

# %%
# An explicit copy to avoid SettingWithCopyWarning
standard_sales = standard_sales.copy()

# 1. Convert InvoiceDate to a true Datetime object
standard_sales['InvoiceDate'] = pd.to_datetime(standard_sales['InvoiceDate'])

# 2. Extract Year and Month (e.g., '2011-11') so we can group by it
standard_sales['YearMonth'] = standard_sales['InvoiceDate'].dt.to_period('M')

# 3. Group by month and sum the sales
monthly_trends = standard_sales.groupby('YearMonth')['TotalSales'].sum().reset_index()

# 4. Convert YearMonth back to a string format
monthly_trends['YearMonth'] = monthly_trends['YearMonth'].astype(str)

# 5. Calculate Month-over-Month growth percentage
monthly_trends['MoM_Growth_Pct'] = monthly_trends['TotalSales'].pct_change() * 100

monthly_trends
# Out:
#    YearMonth  TotalSales  MoM_Growth_Pct
# 0    2010-12  276676.050             NaN
# 1    2011-01  236248.140      -14.612002
# 2    2011-02  224825.800       -4.834891
# 3    2011-03  297096.890       32.145372
# 4    2011-04  256216.991      -13.759787
# 5    2011-05  334938.850       30.724683
# 6    2011-06  303004.100       -9.534502
# 7    2011-07  292205.831       -3.563737
# 8    2011-08  315291.130        7.900355
# 9    2011-09  470518.242       49.232946
# 10   2011-10  532237.050       13.117198
# 11   2011-11  636002.500       19.496097
# 12   2011-12  171412.900      -73.048392

# %% [markdown]
# ## Visualizations

# %%
# Group data by country to see where revenue originates
country_data = standard_sales.groupby('Country')['TotalSales'].sum().reset_index()

# Build an interactive choropleth world map
fig_map = px.choropleth(
    country_data, 
    locations="Country", 
    locationmode="country names",
    color="TotalSales", 
    title="Global Revenue Distribution (Interactive Map)",
    color_continuous_scale=px.colors.sequential.Viridis,
    labels={'TotalSales':'Total Revenue ($)'}
)


fig_map.update_layout(geo=dict(showframe=False, showcoastlines=True))
fig_map.show()
# Out:
# <div>                            <div id="6afd56be-711c-432f-86ab-5c6755f74b85" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6afd56be-711c-432f-86ab-5c6755f74b85")) {                    Plotly.newPlot(                        "6afd56be-711c-432f-86ab-5c6755f74b85",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"Country=%{location}\u003cbr\u003eTotal Revenue ($)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"country names","locations":["Australia","Austria","Bahrain","Belgium","Brazil","Canada","Channel Islands","Cyprus","Czech Republic","Denmark","EIRE","European Community","Finland","France","Germany","Greece","Iceland","Israel","Italy","Japan","Lebanon","Lithuania","Malta","Netherlands","Norway","Poland","Portugal","RSA","Saudi Arabia","Singapore","Spain","Sweden","Switzerland","USA","United Arab Emirates","United Kingdom","Unspecified"],"name":"","z":[9261.66,6292.13,353.4,32296.21,456.84000000000003,2248.32,13015.2,8724.92,494.84,5091.8,104576.13,1084.75,11269.95,126032.33,137243.01,1801.33,3174.62,3547.5,13051.45,1371.44,741.33,391.5,1826.17,11450.74,16210.17,5827.2,20566.64,1002.3100000000001,131.17,2937.14,33166.85,4738.84,28406.25,1755.72,1186.18,3732465.084,2483.35],"type":"choropleth"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth": ...

# %%
# Relationship between unit price and the quantity of customers purchase.


scatter_sample = standard_sales.sample(n=min(5000, len(standard_sales)), random_state=42)

fig_scatter = px.scatter(
    scatter_sample, 
    x="UnitPrice", 
    y="Quantity", 
    color="Country",
    title="Customer Purchase Behavior: Quantity vs Unit Price",
    hover_data=['Description'],
    opacity=0.7
)

fig_scatter.show()
# Out:
# <div>                            <div id="1c776c60-0923-46d8-b81f-28fe04d303f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1c776c60-0923-46d8-b81f-28fe04d303f8")) {                    Plotly.newPlot(                        "1c776c60-0923-46d8-b81f-28fe04d303f8",                        [{"customdata":[["SWEETHEART KEY CABINET"],["RELAX LARGE WOOD LETTERS"],["NUMBER TILE VINTAGE FONT 1"],["SPOTTY BUNTING"],["JUMBO BAG DOILEY PATTERNS"],["PEACE WOODEN BLOCK LETTERS"],["VINTAGE  2 METRE FOLDING RULER"],["SET\u002f4 BUTTERFLY MIRROR MAGNETS"],["CARD DOLLY GIRL "],["WHITE BROCANTE SOAP DISH"],["DOORMAT HEARTS"],["ASSORTED COLOURS SILK FAN"],["RED WOOLLY HOTTIE WHITE HEART."],["CERAMIC CAKE STAND + HANGING CAKES"],["WOODEN REGATTA BUNTING"],["LARGE PINK GLASS SUNDAE DISH"],["SET OF 6 KASHMIR FOLKART BAUBLES"],["HEART WOODEN CHRISTMAS DECORATION"],["HOT WATER BOTTLE BABUSHKA "],["FRENCH LAVENDER SCENT HEART"],["RETROSPOT LAMP"],["SINGLE HEART ZINC T-LIGHT HOLDER"],["COOK WITH WINE METAL SIGN "],["PACK OF 60 PINK PAISLEY CAKE CASES"],["POTTING SHED SEED ENVELOPES"],["VINTAGE UNION JACK CUSHION COVER"],["SPACEBOY BIRTHDAY CARD"],["3 TRADITIONAl BISCUIT CUTTERS  SET"],["WOOD STOCKING CHRISTMAS SCANDISPOT"],["MEMO BOARD COTTAGE DESIGN"],["LARGE PURPLE BABUSHKA NOTEBOOK  "],["SET 6 SCHOOL MILK BOTTLES IN CRATE"],["SPOTTY BUNTING"],["JUMBO BAG SCANDINAVIAN BLUE PAISLEY"],["PINK REGENCY TEACUP AND SAUCER"],["SMALL HEART MEASURING SPOONS"],["SET OF 12 FAIRY CAKE BAKING CASES"],["LUNCH BAG DOLLY GIRL DESIGN"],["GREEN FERN POCKET BOOK"],["CLASSIC CHROME BICYCLE BELL "],["DOORMAT VINTAGE LEAF"],["PACK OF 6 COCKTAIL PARASOL STRAWS"],["ORANGE SCENTED SET\u002f9 T-LIGHTS"],["LUNCH BAG DOILEY PATTERN "],["SWALLOWS GREETING CARD"],["JAM MAKING SET WITH JARS"],["CHOCOLATE HOT WATER BOTTLE"],["12 DAISY PEGS IN WOOD BOX"],["12 PENCILS TALL TUBE WOODLAND"],["GUMBALL COAT RACK"],["SET OF 16 VINTAGE ROSE CUTLERY"],["RECYCLING BAG RETROSPOT "],["VINTAGE CHRISTMAS STOCKING "],["WRAP VINTAGE LEAF DESIGN"],["HAND OVER THE CHOCOLATE   SIGN "],["JUMBO  BAG BAROQUE BLACK WHITE"],["SET OF 20 VINTAGE CHRISTMAS NAPKINS"],["DINOSAURS  WRITING SET "],["LUNCH BAG APPLE DESIGN"],["VINTAGE PAISLEY STATIONERY SET"],["DINOSAUR LUNCH BOX WITH CUTLERY"],["FOLKART STAR CHRISTMAS DECORATIONS"],["CARAVAN SQUARE TISSUE BOX"],["FAIRY CAKE FLANNEL ASSORTED COLOUR"],["200 RED + WHITE BENDY STRAWS"],["SET 36 COLOUR PENCILS LOVE LONDON"],["TRIPLE HOOK ANTIQUE IVORY ROSE"],["APPLE BATH SPONGE"],["RED HANGING HEART T-LIGHT HOLDER"],["SET OF 12 MINI LOAF BAKING CASES"],["GARDENERS KNEELING PAD KEEP CALM "],["JAM JAR WITH PINK LID"],["MAGNETS PACK OF 4 SWALLOWS"],["WHITE HANGING HEART T-LIGHT HOLDER"],["RIBBON REEL HEARTS DESIGN "],["PINK  HONEYCOMB PAPER FAN"],["3 PIECE SPACEBOY COOKIE CUTTER SET"],["WHITE HANGING HEART T-LIGHT HOLDER"],["SET 6 PAPER TABLE LANTERN HEARTS "],["BALLOONS  WRITING SET "],["DECORATIVE WICKER HEART LARGE"],["JAM MAKING SET WITH JARS"],["GINGHAM HEART  DOORSTOP RED"],["TRAVEL CARD WALLET KEEP CALM"],["SQUARE MINI PORTRAIT FRAME"],["LUNCH BAG PINK POLKADOT"],["RED RETROSPOT TRADITIONAL TEAPOT "],["DAISIES  HONEYCOMB GARLAND "],["SET 8 CANDLES VINTAGE DOILY"],["TRADITIONAL MODELLING CLAY"],["HANGING WOOD AND FELT BUTTERFLY "],["HOT WATER BOTTLE TEA AND SYMPATHY"],["ALARM CLOCK BAKELIKE PINK"],["HAND WARMER UNION JACK"],["EASTER TIN CHICKS PINK DAISY"],["36 PENCILS TUBE SKULLS"],["RED RETROSPOT PICNIC BAG"],["RED RETROSPOT CHARLOTTE BAG"],["GLASS HEART T-LIGHT HOLDER "],["TRAVEL CARD WALLET RETROSPOT"],["WICKER STAR "],["FOUR HOOK  WHITE LOVEBIRDS"],["TRAVEL CARD WALLET FLOWER MEADOW"],["SPACEBOY CHILDRENS CUP"],["WOODLAND CHARLOTTE BAG"],["IVORY KITCHEN SCALES"],["PAPER CHAIN KIT VINTAGE CHRISTMAS"],["ALARM CLOCK BAKELIKE  ...
